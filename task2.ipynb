# %%
import csv

with open('pokemon.csv') as file:
    csv_reader_object = csv.reader(file)
    for row in csv_reader_object:
        print("CSV row: {0}".format(row))

# %%
with open('pokemon.csv') as file:
    csv_reader_object = csv.reader(file)
    if csv.Sniffer().has_header:
        next(csv_reader_object)
    for row in csv_reader_object:
        if legendary ='true'
         count+= 1

# %%
#1. count the number of legendary Pokemons and print all the details about them.
import csv
C=0
with open('pokemon.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        X=row['Legendary']
        
        if X == 'TRUE':
           C=C+1  
           print(row['#'],row['Name'],row['Type 1'],row['Type 2'],row['Total'],row['HP'],row['Attack'],row['Defense'],row['Sp. Atk'],row['Sp. Def'],row['Speed'],row['Stage'],row['Legendary'])
print(' the number of legendary pokemon:');print(C)

# %%
#2. Count all the unique Pokemon types in the data set.
import csv
C=0
li=[]
s=set()
with open('pokemon.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        X=row['Type 1']
        y=-['Type 2']
        s.update([X])

              
        
print(len(s))        
print((s))
# Out:
# 15
# {'Psychic', 'Rock', 'Dragon', 'Fire', 'Fairy', 'Normal', 'Ice', 'Grass', 'Fighting', 'Bug', 'Electric', 'Poison', 'Ghost', 'Ground', 'Water'}

# %%
#3. Count the number Pokemons who got a single types.
import csv
C=0
li=[]
with open('pokemon.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        X=row['Type 2']
        
        li.append(X)
               
        

print(li.count(''))
# Out:
# 84

# %%
#3. Count the number Pokemons who got a two types.

import csv
C=0
li=[]
with open('pokemon.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        X=row['Type 2']
        
        li.append(X)
           
k=[]         
for i in li: 
    if i!='' :
        k.append(i)
print(len(k))
# Out:
# 67

# %%
#5. Print the most frequent Pokemon type in the data set.
import csv
C=0
li=[]
li2=[]
with open('pokemon.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        X=row['Type 1']
        z=row['Type 2']
        li.append(X)
        li2.append(z)
           
li3=li+li2
k=[]         
for i in li3: 
    if i!='' :
        k.append(i)
def most_frequent(List): 
    return max(set(List), key = List.count)  
List = k 
print(most_frequent(List))
print(k.count('Poison'))
# Out:
# Poison
# 33

# %%
#6. Find the average HP of all flying Pokemons.
import csv
C=0
li=[]
sum1=0
with open('pokemon.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        X=row['Type 1']
        z=row['Type 2']
       
        if X == 'Flying' or z=='Flying':
           C=C+1
           h=row['HP']
           li.append(h)

for i in range(len(li)):
    li[i] = int(li[i])
           
for ele in range(0, len(li)): 
    sum1 = sum1 + li[ele] 
  
print("the avarage of the HP: ", sum1/C)

# %%
import csv
C=0
li=[]
sum1=0
sum2=0
with open('pokemon.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        X=row['Total']
        
        li.append(X)
for i in range(len(li)):
    li[i] = int(li[i])
k=len(li)    

for ele in range(0, len(li)): 
    sum1 = sum1 + li[ele]
mean = sum1 / k
for ele in range(0, len(li)): 
    sum2 = sum2 +((li[ele] - mean) ** 2)

ver=sum2/k
stv=(ver)**(1/2)
print("the ver of toatal is: ",ver ) 
print("the stv of toatal is: ",stv )

# %%
#8. Find the first 5 Pokemons with the biggest attack power.
from heapq import nlargest
import csv
listof2=[2]
li=[]
li2=[]
li3=[]
li4=[]
li5=[]
li6=[]
nli=[]
nli2=[]
nli3=[]

sum1=0
with open('pokemon.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        X=row['Type 2']
        Y=row['Legendary']
        if X == '' and Y =='FALSE': 
           X2=row['Attack']
           z=row['Sp. Atk']
           n=row['Name']
           li.append(X2)
           li2.append(z)
           nli.append(n)
        elif Y =='TRUE' or  X == '' :
             X2=row['Attack']
             z=row['Sp. Atk']
             n=row['Name']
             li3.append(X2)
             li4.append(z)
             nli2.append(n)
        else:
             X2=row['Attack']
             z=row['Sp. Atk']
             n=row['Name']
             li5.append(X2)
             nli3.append(n)
             li6.append(z)
        
        
       
        
        for i in range(len(li)):
            li[i] = int(li[i])
        for i in range(len(li2)):
            li2[i] = int(li2[i])

        for i in range(len(li3)):
            li3[i] = int(li3[i])
        for i in range(len(li4)):
            li4[i] = int(li4[i])
            
        for i in range(len(li5)):
            li5[i] = int(li5[i])
        for i in range(len(li6)):
            li6[i] = int(li6[i])

        t2=[a*b for a,b in zip(li,li2)]
        t0=[a*b for a,b in zip(li3,li4)]
        t1=[a*b for a,b in zip(li5,li6)]
        

        t00 = [((i * 2)+75) for i in t0]
        t11 = [i * 2 for i in t1]
        dictt2 = dict(zip(nli, t2))
        dictt0 = dict(zip(nli2, t00))
        dictt1 = dict(zip(nli3, t11))
        allpowdic={}
        allpowdic.update(dictt1)
        allpowdic.update(dictt0)
        allpowdic.update(dictt2)
        
        
        fivelargest = nlargest(5, allpowdic, key=allpowdic.get)
print(fivelargest)

# %%
import csv
C=0
li=[]
li2=[]
li3=[]
li4=[]
li5=[]
li6=[]
nli=[]
nli2=[]
nli3=[]
nld=[]
nld1=[]
nld2=[]
nlds=[]
nlds1=[]
nlds2=[]


sum1=0
with open('pokemon.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        X=row['Type 2']
        Y=row['Legendary']
        if X == '' and Y =='FALSE': 
           X2=row['Attack']
           z=row['Sp. Atk']
           n=row['Name']
           d=row['Defense']
           ds=row['Sp. Def']
           H=row['HP']
           li.append(X2)
           li2.append(z)
           nli.append(n)
           nld.append(d)
           nlds.append(ds)
        elif Y =='TRUE' or  X == '' :
             X2=row['Attack']
             z=row['Sp. Atk']
             n=row['Name']
             d=row['Defense']
             ds=row['Sp. Def']
             H=row['HP']
             li3.append(X2)
             li4.append(z)
             nli2.append(n)
             nld1.append(d)
             nlds1.append(ds)
        else:
             X2=row['Attack']
             z=row['Sp. Atk']
             n=row['Name']
             d=row['Defense']
             ds=row['Sp. Def']
             H=row['HP']
             li5.append(X2)
             nli3.append(n)
             li6.append(z)
             nld2.append(d)
             nlds2.append(ds)
        
        
       
        
        for i in range(len(li)):
            li[i] = int(li[i])
        for i in range(len(li2)):
            li2[i] = int(li2[i])

        for i in range(len(li3)):
            li3[i] = int(li3[i])
        for i in range(len(li4)):
            li4[i] = int(li4[i])
            
        for i in range(len(li5)):
            li5[i] = int(li5[i])
        for i in range(len(li6)):
            li6[i] = int(li6[i])
        for i in range(len(nld)):
             nld[i]=int(nld[i])
        for i in range(len(nlds)):
             nlds[i]=int(nlds[i])
        for i in range(len(nld1)):
             nld1[i]=int(nld1[i])
        for i in range(len(nlds1)):
             nlds1[i]=int(nlds1[i])
        for i in range(len(nld2)):
             nld2[i]=int(nld2[i])
        for i in range(len(nlds2)):
             nlds2[i]=int(nlds2[i])
            

        t2=[a*b for a,b in zip(li,li2)]
        t0=[a*b for a,b in zip(li3,li4)]
        t1=[a*b for a,b in zip(li5,li6)]
        
        d2=[a*b for a,b in zip(nld,nlds)]
        d0=[a*b for a,b in zip(nld1,nlds1)]
        d1=[a*b for a,b in zip(nld2,nlds2)]

   
        t00 = [((i * 2)+75) for i in t0]
        t11 = [i * 2 for i in t1]
        
        dd1=[i * 2 for i in d1]
        dd0= [((i * 2)+75) for i in d0]
        
        
        s=[a-b for a,b in zip(t2,d2)]
        s1=[a-b for a,b in zip(dd0,t00)]
        s2=[a-b for a,b in zip(dd1,t11)]
        
        
        
        
        
        dictt2 = dict(zip(nli, s))
        dictt0 = dict(zip(nli2, s1))
        dictt1 = dict(zip(nli3, s2))
        alldifdic={}
        alldifdic.update(dictt1)
        alldifdic.update(dictt0)
        alldifdic.update(dictt2)
        q = dict((k, v) for k, v in alldifdic.items() if (v <= 25 and v >=0))
print(q)
print((len(list(q))))
# Out:
# {'Bulbasaur': 0, 'Slowpoke': 0, 'Ekans': 24, 'Poliwhirl': 0, 'Ditto': 0, 'Snorlax': 0, 'Mew': 0}
# 7

# %%
from heapq import nlargest
import csv
C=0
li=[]
li2=[]
li3=[]
li4=[]
li5=[]
li6=[]
nli=[]
nli2=[]
nli3=[]
nld=[]
nld1=[]
nld2=[]
nlds=[]
nlds1=[]
nlds2=[]
nlh=[]
nlh1=[]
nlh2=[]
xh=0
xh2=0
sum1=0
total=0
resu1=0
resu2=0
with open('pokemon.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        X=row['Type 2']
        Y=row['Legendary']
        if Y =='FALSE': 
           X2=row['Attack']
           z=row['Sp. Atk']
           n=row['Name']
           d=row['Defense']
           ds=row['Sp. Def']
           H=row['HP']
           li.append(X2)
           li2.append(z)
           nli.append(n)
           nld.append(d)
           nlds.append(ds)
           nlh.append(H)
        elif Y =='TRUE' or  X == '' :
             X2=row['Attack']
             z=row['Sp. Atk']
             n=row['Name']
             d=row['Defense']
             ds=row['Sp. Def']
             H=row['HP']
             li3.append(X2)
             li4.append(z)
             nli2.append(n)
             nld1.append(d)
             nlds1.append(ds)
             nlh1.append(H)
        else:
             X2=row['Attack']
             z=row['Sp. Atk']
             n=row['Name']
             d=row['Defense']
             ds=row['Sp. Def']
             H=row['HP']
             li5.append(X2)
             nli3.append(n)
             li6.append(z)
             nld2.append(d)
             nlds2.append(ds)
             nlh2.append(H)
        
        
       
        
        for i in range(len(li)):
            li[i] = int(li[i])
        for i in range(len(li2)):
            li2[i] = int(li2[i])

        for i in range(len(li3)):
            li3[i] = int(li3[i])
        for i in range(len(li4)):
            li4[i] = int(li4[i])
            
        for i in range(len(li5)):
            li5[i] = int(li5[i])
        for i in range(len(li6)):
            li6[i] = int(li6[i])
        for i in range(len(nld)):
             nld[i]=int(nld[i])
        for i in range(len(nlds)):
             nlds[i]=int(nlds[i])
        for i in range(len(nld1)):
             nld1[i]=int(nld1[i])
        for i in range(len(nlds1)):
             nlds1[i]=int(nlds1[i])
        for i in range(len(nld2)):
             nld2[i]=int(nld2[i])
        for i in range(len(nlds2)):
             nlds2[i]=int(nlds2[i])
        for i in range(len(nlh)):
             nlh[i]=int(nlh[i])
        for i in range(len(nlh1)):
             nlh1[i]=int(nlh1[i])
        for i in range(len(nlh2)):
             nlh2[i]=int(nlh2[i])
            

        t2=[a*b for a,b in zip(li,li2)]
        t1=[a*b for a,b in zip(li5,li6)]
        d0=[a*b for a,b in zip(nld1,nlds1)]
        dd0= [((i * 2)+75) for i in d0]
        
   
        
        t11 = [i * 2 for i in t1]
        
        
        
            
            
        su2=sum(dd0)
        hsu=sum(nlh1)
        
                    
        
        dictt2 = dict(zip(nli, map(list, zip(map(int, t2), map(int, nlh)))))
        dictt1 = dict(zip(nli2, map(list, zip(map(int, t11), map(int, nlh2)))))
        
        allpowdic={}
        allpowdic.update(dictt1)
        allpowdic.update(dictt2)
        
        

     
JJ=sorted(allpowdic.values(),reverse=True)
for k,v in JJ:
    
    if xh<=su2 :
        C=C+1
        xh2+=v
        xh += k 
        resu1=xh/hsu
        resu2=su2/xh2
        total=resu1-resu2
        if total>0:
            higheest = nlargest(C, allpowdic, key = allpowdic.get)
            print(total)
            print(higheest)
            print(C)
            
            break
# Out:
# 45.455369175480854
# ['Dragonite', 'Flareon', 'Exeggutor', 'Arcanine', 'Victreebel', 'Mew']
# 6
