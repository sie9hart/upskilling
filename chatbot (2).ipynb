# %%
"""insetruction how use this bot


if u do not use the words that it is know it will give the same answer so this is the word he know
goodbye = exit program
hi are you with any word =greating
what is your name to know his name
how are you with any word=greating
if it see in any word joke it will enter joke mode it will start to tell joke limited bettween 4 type it will ask u what type to listen or read
if u want to close joke mode enter stop it
if u sick it diagnose 3 differant dieses [common_cold,inflammation_appendicitis,urinary_infection] so u need enter all symptoms.
to go into diagnose mode enter sick with any thing or do not feel good with anything 
to exit from diagnose mode enter (thats all)
u can ask for time and date by what time and date is it . and if it like movie,  what kind of food it like or what he want eat
u can ask 
[do you need any help,how was your day,how are you feeling,how it going]
u can play tic tac toe if u enter play with anything
if u annoyed it it will respose but with response it will type somthing u do not like it
"""



import datetime
import random
import re
import TicTacToe1
import sys, importlib
from time import sleep


def s():
    load = '...'
    for i in range(3):
        print(load[i], sep=' ', end=' ', flush=True); sleep(.5)







c=0
x=0
li=[]
common_cold=['runny nose','cough','phlegm production','chills and fever','generalized weakness','muscle pain']
inflammation_appendicitis=['pain started from the belly button and moved to the right lower side of the belly','pain started at the right lower side of the belly','nausea','loss of appetite','chills and fever','burning sensation with urination','pervious episode of same attack','constipation or diarrhea']
urinary_infection=['pain below the belly button',' it move to the back','pain with urination','abnormal color of the urine','bad smile of the urine','chills and fever','loin pain']
while x!='goodbye':
     x=input("")
     
     if re.findall('hi.*?',x):
        li=["hey!",'hello']
        s()
        print('\n',random.choice(li))
        c=c+1
          if c>3:
             print('if u ask this quastion again i swar to God that i will kick ur ass')
     elif re.findall('how are you.*?',x):
          li=["i'm fine thank you","i'm good and you"]
          s()
          print('\n',random.choice(li))
          c=c+1
          if c>3:
             print('if u ask this quastion again i swar to God that i will kick ur ass')
     
     elif re.findall('joke.*?',x):
          li=["pun","bar_joke","knock_knock","dumb_funny"]
          s()
          print("\nBugs are all fixed now! Happy cringe/laughing! ;)")
          print('choose from this list the joke type',li)
          
          
          
          while x!='stop it':
                x=input("")
                Joke=x
                if Joke == "pun":
                   s()
                   pun = random.choice(["Why Couldn't The bike Stand on it's own? It was Two Tired!", "Whoever Stole My Copy of Microsoft Office is in Big Trouble! You got my word!", "Need an ark? I Noah Guy!", "Frog Parking Only! Any one else will be toad away.", "Renewable Energy? I'm a big Fan!", "Becoming a vegetarian is a huge missed steak!", "Have you ever eight a clock? It's so time-consuming!"])
                   print('\n',str(pun))
                   print("\n=============")
   

                elif Joke == "bar_joke":
                   s()
                   bar = random.choice(["'Poor Old fool,' thought the well-dressed gentleman as he watched an old man fish in a puddle outside a pub. So he invited the old man inside for a drink. As they sipped their whiskeys, the gentleman thought he'd humor the old man and asked, 'So how many have you caught today?' The old man replied, 'Your the eighth", "Infinitely many mathematicians walk into a bar. The first says, 'I'll have a beer.' The second says, 'I'll have half a beer.' The third says, 'I'll have a quarter of a beer.' Before anyone else can speak, the barman fills up exactly two glasses of beer and serves them. 'Come on, now,' he says to the group, 'You guys have got to learn your limits.'", "At an all-you-can-eat buffet, my nine-year-old was excited to find a chocolate milk machine. But her aunt did not approve. 'Chocolate milk for dinner?' she asked. 'It's delicious!' said my daughter. Her aunt shrugged. 'Well, its 8 a.m. somewhere.'", "The barman says, 'We don’t serve time travelers in here.' A time traveler walks into a bar."])
                   print('\n',str(bar))
                   print("\n=============")
 
    
                elif Joke == "knock_knock":
                    s()
                    knock_knock = random.choice(["'Knock-Knock!' 'Who's There?' 'Control Freak' 'Con-' 'Now you say Control Freak Who.'", "'Knock-Knock!' 'Who's There?' 'Ho-Ho' 'Ho-Ho Who?' 'You could use a little work on your santa impression.'", "'Knock-Knock!' 'Who's There?' 'Santa' 'Santa Who?' 'I santa email I'd be here and I'm still waiting out in the cold!'", "'Knock-Knock!' 'Who's there?' 'Snow' 'Snow Who?' 'Snow Use! I forgot my name again.'"])
                    print('\n',str(knock_knock))
                    print("\n=============")
    
    
                elif Joke == "dumb_funny":
                    s()
                    reg = random.choice(["Client: Please remove the unnecessary circle at the end of the sentence.  Me: You mean … the period?  Client: I don’t care what you designers call it; it is unsightly. Delete it.", "When asked for his name by the coffee shop clerk, my brother-in-law answered, 'Marc, with a C.' Minutes later, he was handed his coffee with his name written on the side: Cark.", "An insurance agent called our medical office. One of our doctors had filled out a medically necessary leave-of-absence form for a patient, but, the agent said, the patient had altered it. The giveaway? The return-to-work date had been changed to February 30.", "A defendant isn't happy with how things are going in court, so he gives the judge a hard time.  Judge: 'Where do you work?'  Defendant: 'Here and there.'  Judge: 'What do you do for a living?'  Defendant: 'This and that.'  Judge: 'Take him away.'  Defendant: 'Wait; when will I get out?'  Judge: 'Sooner or later.'", "A first-grade teacher can’t believe her student isn’t hepped up about the Super Bowl. 'It’s a huge event. Why aren’t you excited?'   'Because I’m not a football fan. My parents love basketball, so I do too,' says the student.  'Well, that’s a lousy reason,' says the teacher. 'What if your parents were morons? What would you be then?'  'Then I’d be a football fan.'", "While on patrol, I arrested a burglar who’d injured himself running from a home. He told me he’d broken in and unhooked the phone before searching for valuables. But he’d panicked when he heard a woman’s voice. I entered the house and heard the same voice: “If you’d like to make a call, please hang up and try your call again.”"])
                    print('\n',str(reg))
                    print("\n=============")
                elif Joke=='stop it':
                     print()
                    
                else:
                    print('i do not no jokes about this subject')
   
    
    
    
     elif re.findall('what is your name.*?',x):
          s()
          print('\nmy name is k')
          c=c+1
          if c>3:
             print('if u ask this quastion again i swar to God that i will kick ur ass')
     
     elif re.findall('eat|food.*?',x):
          
          if re.findall('food.*?',x):
                 
                 li=["i like lazania","i like kabab"]
                 s()
                 print('\n',random.choice(li))
                 c=c+1
                 if c>3:
                    print('if u ask this quastion again i swar to God that i will kick ur ass')
                 
          else:
                 li=["i want to eat lazania","i want to eat kabab"]
                 s()
                 print('\n',random.choice(li))
                 c=c+1
                 if c>3:
                    print('if u ask this quastion again i swar to God that i will kick ur ass')
               
        
     elif re.findall('movie.*?',x):
        s()
        print('\ni like movies and i will give you my favourite site to watch movies')
        print('https://www.netflix.com/')
        print('https://egybest.io/')
        c=c+1
        if c>3:
            print('if u ask this quastion again i swar to God that i will kick ur ass')
         
     elif re.findall('play.*?',x):
          s()
          print('\ndo you like to play tic tac toe')
          importlib.reload(sys.modules['TicTacToe1'])
          from TicTacToe1 import exe
          exe()
     elif x=='goodbye':
          print()
     
    
     elif re.findall('sick|do not feel good',x):
          s();print('\n forget to tell i am studing medicine tell me your symptoms')
          while x!='thats all':
                
                x=input('')
                li.append(x)
                
          result=all(elem in li for elem in common_cold)
          result1 =  all(elem in li for elem in inflammation_appendicitis)
          result3 =  all(elem in li for elem in urinary_infection) 
          if result:
               s();print('\ncommon_cold')
               li.clear() 
          elif result1:
               s();print('\ninflammation_appendicitis')
               li.clear()
          elif result3:
               s();print('\nurinary_infection')
               li.clear()
          else:
               s();print('\n i do no this disease')
               li.clear()
     elif x=='Single Or Taken':
          s()
          print('single :(')
          c=c+1
          if c>3:
             print('if u ask this quastion again i swar to God that i will kick ur ass')
     elif x=='what do you do in your free time':
          file1 = open("k.txt","r+")
          
          s()
          print ('\n',random.choice(file1.readlines())) 
          file1.close()
          c=c+1
          if c>3:
             print('if u ask this quastion again i swar to God that i will kick ur ass')
       
     elif re.findall('what time and date is it|do you have the time.*?',x): 
          s()
          print('\nthe date and time:' )
          print(datetime.datetime.now())
          c=c+1
          if c>3:
             print('if u ask this quastion again i swar to God that i will kick ur ass')
     
    
     
     elif re.findall('do you need any help|do you need any help.*?',x): 
          file1 = open("kkk.txt","r+")          
          s()
          print ('\n',random.choice(file1.readlines())) 
          
          c=c+1
          if c>3:
             print('if u ask this quastion again i swar to God that i will kick ur ass')
                
              
            
            
            
     elif re.findall('how it going.*?',x):
          file1 = open("kkkk.txt","r+")
          
          s()
          print ('\n',random.choice(file1.readlines()))
          file1.close()
          c=c+1
          if c>3:
                print('if u ask this quastion again i swar to God that i will kick ur ass')
                    
                    
                    
     elif re.findall('how are you feeling.*?',x):
          file1 = open("kkkkk.txt","r+")
          
          s()
          print ('\n',random.choice(file1.readlines()))
          file1.close()
          c=c+1
          if c>3:
                 print('if u ask this quastion again i swar to God that i will kick ur ass')
                    
                    
          
         
     elif re.findall('how was your day.*?',x):
          file1 = open("k6.txt","r+")
           
          s()
          print ('\n',random.choice(file1.readlines()))
          file1.close()
          c=c+1
          if c>3:
                print('if u ask this quastion again i swar to God that i will kick ur ass')       
     else:
          s()
          print(" \n sorry i am dummy bot because the  instructor of my developer tell him that he can't use advanced lib to creat my brain ")
# Out:
# help
# . . .
#  sorry i am dummy bot because the  instructor of my developer tell him that he can't use advanced lib to creat my brain
# goodbye
