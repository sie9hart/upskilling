# %%
import random
import re
import TicTacToe1
import sys, importlib








print("this bot is dummy bot u can use some specific word  to exit enter goodbay ")
x=0
li=[]
common_cold=['runny nose','cough','phlegm production','chills and fever','generalized weakness','muscle pain']
inflammation_appendicitis=['pain started from the belly button and moved to the right lower side of the belly','pain started at the right lower side of the belly','nausea','loss of appetite','chills and fever','burning sensation with urination','pervious episode of same attack','constipation or diarrhea']
urinary_infection=['pain below the belly button',' it move to the back','pain with urination','abnormal color of the urine','bad smile of the urine','chills and fever','loin pain']
while x!='goodbye':
     x=input("")
     
     if x=='hi':
        li=["hey!",'hello']
        print(random.choice(li))
     elif x=='how are you':
          li=["i'm fine thank you","i'm good and you"]
          print(random.choice(li))
        
     elif x=='what is your name':
          print('my name is k')
     
     elif re.findall('eat|food.*?',x):
          if re.findall('food.*?',x):
                 li=["i like lazania","i like kabab"]
                 print(random.choice(li))
          else:
                 li=["i want to eat lazania","i want to eat kabab"]
                 print(random.choice(li))
               
        
     elif re.findall('movie.*?',x):
        print('i like movies and i will give you my favourite site to watch movies')
        print('https://www.netflix.com/')
        print('https://egybest.io/')
         
     elif re.findall('play.*?',x):
          print('do you like to play tic tac toe')
          importlib.reload(sys.modules['TicTacToe1'])
          from TicTacToe1 import exe
          exe()
     elif x=='goodbye':
          print()
     
    
     elif re.findall('sick|[do not feel good].*?',x):
          print('i forget to tell i am studing medicine tell me your symptoms')
          while x!='thats all':
                
                x=input('')
                li.append(x)
                
          result =  all(elem in li  for elem in common_cold)
          result1 =  all(elem in li  for elem in inflammation_appendicitis)
          result2 =  all(elem in li  for elem in urinary_infection) 
          if result:
               print('common_cold')
               li.clear() 
          elif result1:
               print('inflammation_appendicitis')
               li.clear()
          elif result2:
               print('urinary_infection')
               li.clear()
          else:
               print('i do no this disease')
               li.clear()
        
    
     else:
          print("  sorry i am dummy bot because the  instructor of my developer tell him that he can't use advanced lib to creat my brain ")
# Out:
# this bot is dummy bot u can use some specific word with it like (hi,movie,play) and one sentence if u want to exit enter goodbay
# sick
# i forget to tell i am studing medicine tell me your symptoms
# runny nose
# cough
# phlegm production
# chills and fever
# generalized weakness
# muscle pain
# thats all
# common_cold
# goodbye
